# %%
import numpy as np
import pandas as pd
from linearmodels import PanelOLS
from linearmodels import RandomEffects
import statsmodels as sm

# %%
from linearmodels.datasets import jobtraining

# %%
from statsmodels.datasets import grunfeld
data = grunfeld.load_pandas().data
data = data.set_index(["firm","year"])
print(data.head())
# Out:
#                        invest   value  capital
# firm           year
# General Motors 1935.0   317.6  3078.5      2.8
#                1936.0   391.8  4661.7     52.6
#                1937.0   410.6  5387.1    156.9
#                1938.0   257.7  2792.2    209.2
#                1939.0   330.8  4313.2    203.4

# %%
data
# Out:
#                         invest     value  capital
# firm           year
# General Motors 1935.0  317.600  3078.500    2.800
#                1936.0  391.800  4661.700   52.600
#                1937.0  410.600  5387.100  156.900
#                1938.0  257.700  2792.200  209.200
#                1939.0  330.800  4313.200  203.400
# ...                        ...       ...      ...
# American Steel 1950.0    4.770    36.494   75.847
#                1951.0    6.532    46.082   77.367
#                1952.0    7.329    57.616   78.631
#                1953.0    9.020    57.441   80.215
#                1954.0    6.281    47.165   83.788
#
# [220 rows x 3 columns]

# %%
from linearmodels.panel import PanelOLS
import statsmodels.api as sm
exog = sm.add_constant(data[['value','capital']])
grunfeld_fe = PanelOLS(data['invest'], exog, entity_effects=True, time_effects=True)
grunfeld_fe = grunfeld_fe.fit()
print(grunfeld_fe)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                 invest   R-squared:                        0.7667
# Estimator:                   PanelOLS   R-squared (Between):              0.8193
# No. Observations:                 220   R-squared (Within):               0.7667
# Date:                Wed, Mar 03 2021   R-squared (Overall):              0.8071
# Time:                        18:26:01   Log-likelihood                   -1167.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      340.08
# Entities:                          11   P-value                           0.0000
# Avg Obs:                       20.000   Distribution:                   F(2,207)
# Min Obs:                       20.000
# Max Obs:                       20.000   F-statistic (robust):             340.08
#                                         P-value                           0.0000
# ...

# %%
jobtraining
# Out:
# <module 'linearmodels.datasets.jobtraining' from '/opt/anaconda3/lib/python3.8/site-packages/linearmodels/datasets/jobtraining/__init__.py'>

# %%
data = jobtraining.load()
year = pd.Categorical(data.year)
data = data.set_index(["fcode", "year"])
data["year"] = year

# %%
data
# Out:
#              employ       sales   avgsal  scrap  rework  tothrs  union  grant  \
# fcode  year
# 410032 1987   100.0  47000000.0  35000.0    NaN     NaN    12.0      0      0
#        1988   131.0  43000000.0  37000.0    NaN     NaN     8.0      0      0
#        1989   123.0  49000000.0  39000.0    NaN     NaN     8.0      0      0
# 410440 1987    12.0   1560000.0  10500.0    NaN     NaN    12.0      0      0
#        1988    13.0   1970000.0  11000.0    NaN     NaN    12.0      0      0
# ...             ...         ...      ...    ...     ...     ...    ...    ...
# 419483 1988   108.0  11500000.0  14810.0   25.0     NaN     0.0      1      0
#        1989   129.0  12000000.0  14227.0   30.0     NaN    20.0      1      0
# 419486 1987    80.0   7000000.0  16000.0    NaN     NaN     0.0      0      0
#        1988    90.0   8500000.0  17000.0    NaN     NaN     0.0      0      0
#        1989   100.0   9900000.0  18000.0    NaN     NaN    40.0      0      1
#
# ...

# %%
exog_vars = 
exog = sm.add_constant(data[exog_vars])
mod = RandomEffects(data.clscrap, exog)
re_res = mod.fit()
print(re_res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0129648bfc75> in <module>
#       1 exog_vars = ["grant", "employ"]
# ----> 2 exog = sm.add_constant(data[exog_vars])
#       3 mod = RandomEffects(data.clscrap, exog)
#       4 re_res = mod.fit()
#       5 print(re_res)
#
# AttributeError: module 'statsmodels' has no attribute 'add_constant'

# %%
import statsmodels.api as sm  clscrap ~ 1 + grant + employ + C(fcode)

# %%
data["year"] = pd.Categorical(data.year)
Y = duncan_prestige.data['clscrap']
X = duncan_prestige.data['education']
X = sm.add_constant(X)
FE_ols = sm.OLS().fit()
print(FE_ols.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-f4d5c3a23c9b> in <module>
#       1 data["year"] = pd.Categorical(data.year)
# ----> 2 FE_ols = sm.OLS(formula="clscrap ~ 1 + grant + employ + C(fcode)", data = data).fit()
#       3 print(FE_ols.summary())
#
# TypeError: __init__() missing 1 required positional argument: 'endog'
